# %% [markdown]
# # Priority 1 Demo — Hepatic Vascular Twin
#
# End-to-end demonstration of the Priority 1 synthetic prototype:
#
# 1. Generate healthy and fragile synthetic networks
# 2. Compute graph and spectral metrics
# 3. Extract topological features
# 4. Run perturbation studies and compute HVRI
# 5. Save figures to `results/figures/`
#
# > **Note:** This notebook is a scaffold placeholder. Implement modules per `ARCHITECTURE.md` before running cells.

# %%
# Scaffold imports — implementations pending
from hepatic_vascular_twin.experiments.synthetic_tests import run_priority1_synthetic_experiment

# Uncomment when implemented:
# results = run_priority1_synthetic_experiment(seed=42)
# print(results)
